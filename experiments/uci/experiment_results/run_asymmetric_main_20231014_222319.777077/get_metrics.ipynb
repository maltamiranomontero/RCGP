# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('metrics.csv')

# %%
data
# Out:
#                                    run_id        dataset      model  \
# 0    run_full_main_20231010_174208.979434      tiny_sine        gpr
# 1    run_full_main_20231010_174208.979434      tiny_sine        gpr
# 2    run_full_main_20231010_174208.979434      tiny_sine        gpr
# 3    run_full_main_20231010_174208.979434      tiny_sine        gpr
# 4    run_full_main_20231010_174208.979434      tiny_sine      t_vgp
# ..                                    ...            ...        ...
# 851  run_full_main_20231010_174208.979434  yacht_focused      t_vgp
# 852  run_full_main_20231010_174208.979434  yacht_focused  rtgpr_irq
# 853  run_full_main_20231010_174208.979434  yacht_focused  rtgpr_irq
# 854  run_full_main_20231010_174208.979434  yacht_focused  rtgpr_irq
# 855  run_full_main_20231010_174208.979434  yacht_focused  rtgpr_irq
#
#      do_compile  do_optimise  repetition         metric      value
# 0          True         True           0  training_time   0.996440
# 1          True         True           0           nlpd  -4.995741
# 2          True         True           0            mae   0.133590
# 3          True         True           0           rmse   0.160971
# 4          True         True           0  training_time   2.255664
# ..          ...          ...         ...            ...        ...
# 851        True         True           2           rmse   0.555300
# 852        True         True           2  training_time   1.458562
# 853        True         True           2           nlpd -11.220214
# 854        True         True           2            mae   0.077467
# 855        True         True           2           rmse   0.135907
#
# [856 rows x 8 columns]

# %%
data[['dataset','model','metric','value']].groupby(['dataset','model','metric']).aggregate(['mean','std']).to_csv('summary.csv')
