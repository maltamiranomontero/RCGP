# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('metrics.csv')

# %%
data
# Out:
#                                       run_id            dataset      model  \
# 0    run_focused_main_20231014_233419.879672     boston_focused        gpr
# 1    run_focused_main_20231014_233419.879672     boston_focused        gpr
# 2    run_focused_main_20231014_233419.879672     boston_focused        gpr
# 3    run_focused_main_20231014_233419.879672     boston_focused        gpr
# 4    run_focused_main_20231014_233419.879672     boston_focused      t_vgp
# ..                                       ...                ...        ...
# 451  run_focused_main_20231014_233419.879672  synthetic_focused      t_vgp
# 452  run_focused_main_20231014_233419.879672  synthetic_focused  rtgpr_irq
# 453  run_focused_main_20231014_233419.879672  synthetic_focused  rtgpr_irq
# 454  run_focused_main_20231014_233419.879672  synthetic_focused  rtgpr_irq
# 455  run_focused_main_20231014_233419.879672  synthetic_focused  rtgpr_irq
#
#      do_compile  do_optimise  repetition         metric      value
# 0          True         True           0  training_time   2.553095
# 1          True         True           0           nlpd  13.540280
# 2          True         True           0            mae   0.278563
# 3          True         True           0           rmse   0.391572
# 4          True         True           0  training_time  34.013625
# ..          ...          ...         ...            ...        ...
# 451        True         True           9           rmse   0.516492
# 452        True         True           9  training_time   1.427411
# 453        True         True           9           nlpd  24.051015
# 454        True         True           9            mae   0.165998
# 455        True         True           9           rmse   0.290790
#
# [456 rows x 8 columns]

# %%
data[['dataset','model','metric','value']].groupby(['dataset','model','metric']).aggregate(['mean','std']).to_csv('summary.csv')
