# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('metrics.csv')

# %%
data
# Out:
#                                       run_id            dataset      model  \
# 0    run_uniform_main_20231021_194401.253845     boston_uniform        gpr
# 1    run_uniform_main_20231021_194401.253845     boston_uniform        gpr
# 2    run_uniform_main_20231021_194401.253845     boston_uniform        gpr
# 3    run_uniform_main_20231021_194401.253845     boston_uniform        gpr
# 4    run_uniform_main_20231021_194401.253845     boston_uniform      t_vgp
# ..                                       ...                ...        ...
# 635  run_uniform_main_20231021_194401.253845  synthetic_uniform  rtgpr_irq
# 636  run_uniform_main_20231021_194401.253845  synthetic_uniform      gpr_2
# 637  run_uniform_main_20231021_194401.253845  synthetic_uniform      gpr_2
# 638  run_uniform_main_20231021_194401.253845  synthetic_uniform      gpr_2
# 639  run_uniform_main_20231021_194401.253845  synthetic_uniform      gpr_2
#
#      do_compile  do_optimise  repetition         metric         value
# 0          True         True           0  training_time  2.072231e+00
# 1          True         True           0           nlpd  9.349417e+01
# 2          True         True           0            mae  4.173768e-01
# 3          True         True           0           rmse  5.203696e-01
# 4          True         True           0  training_time  2.531888e+01
# ..          ...          ...         ...            ...           ...
# 635        True         True           9           rmse  2.850280e-01
# 636        True         True           9  training_time  1.340016e+00
# 637        True         True           9           nlpd  1.165910e+07
# 638        True         True           9            mae  6.822226e-01
# 639        True         True           9           rmse  8.860582e-01
#
# [640 rows x 8 columns]

# %%
data[['dataset','model','metric','value']].groupby(['dataset','model','metric']).aggregate(['mean','std']).to_csv('summary.csv')
